# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzeh-khanpour/Feynman-Diagrams/blob/main/gamma-gamma-LHC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
pip install feynman
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = plt.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
#diagram.text(.5,0.9,"LHeC", fontsize=40)

in1 = diagram.vertex(xy=(.1,.8), marker='')
in2= diagram.vertex(xy=(.1,.2), marker='')
v1 = diagram.vertex(xy=(0.4,0.7),marker='')
v2 = diagram.vertex(xy=(0.4,0.3),marker='')

v3 = diagram.vertex(xy=(.65,.5),marker='')
v4 = diagram.vertex(xy=(.65,.55),marker='')
vw1 = diagram.vertex(xy=(.67,.54),marker='')
vw2 = diagram.vertex(xy=(.67,.51),marker='')

out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')

Wplusout = diagram.vertex(xy=(0.85, 0.65), marker='')
Wminusout = diagram.vertex(xy=(0.85, 0.4), marker='')

lw = 5
e1 = diagram.line(in1, v1, style='line', color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
p1 = diagram.line(in2, v2, style='line', color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))

g1 = diagram.line(v4, v1, style='wiggly')
g2 = diagram.line(v3, v2, style='wiggly')

W1 = diagram.line(vw1, Wplusout,  arrow=True, style='dashed', color='green', lw=3, dashes=(4, 2),arrow_param=dict(color='green', length=0.08, width=0.02))
W2 = diagram.line(vw2, Wminusout, arrow=True, style='dashed', color='green', lw=3, dashes=(4, 2),arrow_param=dict(color='green', length=0.08, width=0.02))

t3 = diagram.line(v1, out1,  color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
t4 = diagram.line(v2, out2 , color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))

e1.text(r"$p$",fontsize=40)
p1.text(r"$p$",fontsize=40)
g1.text(r"$\gamma$",fontsize=40)
g2.text(r"$\gamma$",fontsize=40)
t3.text(r"$p^{(*)}$",fontsize=40)
t4.text(r"$p^{(*)}$",fontsize=40)
diagram.text(0.75,0.52,r"$W^{\pm}/ZZ$",fontsize=30, color='g')
#diagram.text(0.82,0.45,r"$W^-/Z$",fontsize=30, color='g')

O = diagram.operator([v4,v3],color='k')
#W1.text("$W^+$", fontsize=35)
#W2.text("$W^-$", fontsize=35)
diagram.plot()
plt.savefig('plot_LHC.pdf')
plt.savefig('plot_LHC.jpg')
plt.show()
# Out:
# /home/hamzeh-khanpour/.local/lib/python3.8/site-packages/feynman/vectors.py:105: RuntimeWarning: divide by zero encountered in double_scalars
#   angle = np.arctan(v[1] / v[0])
# /home/hamzeh-khanpour/.local/lib/python3.8/site-packages/feynman/core/operators.py:178: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ellipse = mpa.Ellipse(center, width, height, angle=angle, **self.style)

# %%
import matplotlib.pyplot as plt

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = plt.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
#diagram.text(.5,0.9,"LHeC", fontsize=40)

in1 = diagram.vertex(xy=(.1,.8), marker='')
in2= diagram.vertex(xy=(.1,.2), marker='')
v1 = diagram.vertex(xy=(0.4,0.7),marker='')
v2 = diagram.vertex(xy=(0.4,0.3),marker='')

v3 = diagram.vertex(xy=(.65,.5),marker='')
v4 = diagram.vertex(xy=(.65,.55),marker='')
vw1 = diagram.vertex(xy=(.67,.54),marker='')
vw2 = diagram.vertex(xy=(.67,.51),marker='')

out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')

Wplusout = diagram.vertex(xy=(0.85, 0.65), marker='')
Wminusout = diagram.vertex(xy=(0.85, 0.4), marker='')

lw = 5
e1 = diagram.line(in1, v1, style='line', color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1 = diagram.line(in2, v2, style='line', color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))

g1 = diagram.line(v4, v1, style='wiggly')
g2 = diagram.line(v3, v2, style='wiggly')

W1 = diagram.line(vw1, Wplusout,  arrow=True, style='dashed', color='green', lw=3, dashes=(4, 2),arrow_param=dict(color='green', length=0.08, width=0.02))
W2 = diagram.line(vw2, Wminusout, arrow=True, style='dashed', color='green', lw=3, dashes=(4, 2),arrow_param=dict(color='green', length=0.08, width=0.02))

t3 = diagram.line(v1, out1,  color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
t4 = diagram.line(v2, out2 , color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))

e1.text(r"$e$",fontsize=40)
p1.text(r"$p$",fontsize=40)
g1.text(r"$\gamma$",fontsize=40)
g2.text(r"$\gamma$",fontsize=40)
t3.text(r"$e$",fontsize=40)
t4.text(r"$p^{(*)}$",fontsize=40)
diagram.text(0.75,0.52,r"$W^{\pm}/ZZ$",fontsize=30, color='g')
#diagram.text(0.82,0.45,r"$W^-/Z$",fontsize=30, color='g')

O = diagram.operator([v4,v3],color='k')
#W1.text("$W^+$", fontsize=35)
#W2.text("$W^-$", fontsize=35)
diagram.plot()
plt.savefig('plot_LHeC.pdf')
plt.savefig('plot_LHeC.jpg')
plt.show()
# Out:
# /home/hamzeh-khanpour/.local/lib/python3.8/site-packages/feynman/vectors.py:105: RuntimeWarning: divide by zero encountered in double_scalars
#   angle = np.arctan(v[1] / v[0])
# /home/hamzeh-khanpour/.local/lib/python3.8/site-packages/feynman/core/operators.py:178: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ellipse = mpa.Ellipse(center, width, height, angle=angle, **self.style)

# %%
import matplotlib.pyplot as plt

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = plt.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
#diagram.text(.5,0.9,"LHeC", fontsize=40)

in1 = diagram.vertex(xy=(.1,.8), marker='')
in2= diagram.vertex(xy=(.1,.2), marker='')
v1 = diagram.vertex(xy=(0.5,0.7),marker='')
v2 = diagram.vertex(xy=(0.5,0.3),marker='')

v3 = diagram.vertex(xy=(.65,.5),marker='')
v4 = diagram.vertex(xy=(.65,.55),marker='')
vw1 = diagram.vertex(xy=(.67,.54),marker='')
vw2 = diagram.vertex(xy=(.67,.51),marker='')

out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')

Wplusout = diagram.vertex(xy=(0.85, 0.65), marker='')
Wminusout = diagram.vertex(xy=(0.85, 0.4), marker='')

lw = 5
e1 = diagram.line(in1, v1, style='wiggly', color='k')
p1 = diagram.line(in2, v2, style='wiggly', color='k')

g1 = diagram.line(v2, v1, style='dashed', color='g', arrow=False)
#g2 = diagram.line(v3, v2, style='wiggly')


t3 = diagram.line(v1, out1 , style='dashed', color='g', arrow_param=dict(color='g', length=0.08, width=0.02))
t4 = diagram.line(v2, out2 , style='dashed', color='g', arrow_param=dict(color='g', length=0.08, width=0.02))

e1.text(r"$\gamma$",fontsize=40)
p1.text(r"$\gamma$",fontsize=40)
g1.text(r"$W$",fontsize=40,color='g')
g2.text(r"$\gamma$",fontsize=40)
t3.text(r"$W^+$",fontsize=40,color='g')
t4.text(r"$W^-$",fontsize=40, color='g')
#diagram.text(0.75,0.52,r"$W^{\pm}/ZZ$",fontsize=30, color='g')
diagram.plot()
plt.savefig('plot_yyww1.pdf')
plt.savefig('plot_yyww1.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = plt.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
#diagram.text(.5,0.9,"LHeC", fontsize=40)

in1 = diagram.vertex(xy=(.1,.8), marker='')
in2= diagram.vertex(xy=(.1,.2), marker='')
v1 = diagram.vertex(xy=(0.5,0.7),marker='')
v2 = diagram.vertex(xy=(0.5,0.3),marker='')
v3 = diagram.vertex(xy=(.5,.5),marker='')


out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')

lw = 5
e1 = diagram.line(in1, v3, style='wiggly', color='k')
p1 = diagram.line(in2, v3, style='wiggly', color='k')

t3 = diagram.line(v3, out1 , style='dashed', color='g', arrow_param=dict(color='g', length=0.08, width=0.02))
t4 = diagram.line(v3, out2 , style='dashed', color='g', arrow_param=dict(color='g', length=0.08, width=0.02))

e1.text(r"$\gamma$",fontsize=40)
#p1.text(r"$\gamma$",fontsize=40)
diagram.text(0.27,0.25,r"$\gamma$",fontsize=40)
g1.text(r"$W$",fontsize=40,color='g')
g2.text(r"$\gamma$",fontsize=40)
t3.text(r"$W^+$",fontsize=40,color='g')
#t4.text(r"$W^-$",fontsize=40, color='g')
diagram.text(0.78,0.4,r"$W^{-}$",fontsize=40, color='g')
diagram.plot()
plt.savefig('plot_yyww2.pdf')
plt.savefig('plot_yyww2.jpg')
plt.show()

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.3,.3), marker='')
vqed = diagram.vertex(xy=(.3,.7), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.8,.65), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.8,.6), marker='') ###
outqb   = diagram.vertex(xy=(.8,.425), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
e2     = diagram.line(vqed, out1, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qb     = diagram.line(v5, outqb , color='black', lw=lw, arrow=False)
qloop  = diagram.line(v3,vx , color='black', lw=lw, arrow=False)## upward quark line
qout   = diagram.line(vx, outX, color='black', lw=lw,arrow=False)#,arrow=True)
p2     = diagram.line(v1, out2, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
gamma  = diagram.line(vqed, vx, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)
gamma2 = diagram.line(v1, v4, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)
ppm    = diagram.line(vtautop, outx1 , color='black', lw=lw, arrow=False)
nutau1 = diagram.line(vtautop, outx2 , color='black', lw=lw, arrow=False)
lep    = diagram.line(vtaubot, outx4 , color='black', lw=lw, arrow=False)
nutau2 = diagram.line(vtaubot, outx3 , color='black', lw=lw, arrow=False)

O = diagram.operator([v4,v3], color='k')
###################################################################################
e1.text(r"$e$" ,fontsize=40, color='k')
e2.text(r"$e$" ,fontsize=40, color='k')
p1.text(r"$p$" ,fontsize=40)
p2.text(r"$p^{(*)}$" ,fontsize=40)
#pomreg.text(r"$x_{I\!P}$",fontsize=40)
#beta.text(r"$\beta$",fontsize=40)
###################################################################################
#wz1.text(r"$\gamma^*q$",fontsize=40,color='g')
diagram.text(0.50, 0.65,r"$\tau$",fontsize=40,color='k')
diagram.text(0.85, 0.65,r"$\pi^{\pm}$",fontsize=40,color='k')
diagram.text(0.85, 0.60,r"$\pi^{0}$",fontsize=40,color='k')
diagram.text(0.85, 0.55,r"$\nu_{\tau}$",fontsize=40,color='k')
diagram.text(0.50, 0.475,r"$\tau$",fontsize=40,color='k')
diagram.text(0.85, 0.475,r"$\nu_{\tau}$",fontsize=40,color='k')
diagram.text(0.85, 0.425,r"$\nu_{l}$",fontsize=40,color='k')
diagram.text(0.85, 0.375,r"$l$",fontsize=40,color='k')
diagram.text(0.45, 0.375,r"$\delta a_{\tau}$",fontsize=40,color='k')
gamma.text(r"$\gamma$",fontsize=40,color='g')
diagram.text(0.32, 0.375,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_yytau.jpg')
matplotlib.pyplot.savefig('plot_yytau.pdf')
matplotlib.pyplot.show()
# Out:
# /home/hamzeh-khanpour/.local/lib/python3.8/site-packages/feynman/vectors.py:105: RuntimeWarning: divide by zero encountered in double_scalars
#   angle = np.arctan(v[1] / v[0])
# /home/hamzeh-khanpour/.local/lib/python3.8/site-packages/feynman/core/operators.py:178: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ellipse = mpa.Ellipse(center, width, height, angle=angle, **self.style)

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.3,.3), marker='')
vqed = diagram.vertex(xy=(.3,.7), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.8,.65), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.8,.6), marker='') ###
outqb   = diagram.vertex(xy=(.8,.4), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
e2     = diagram.line(vqed, out1, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qb     = diagram.line(v4, outqb , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qloop  = diagram.line(vx,v4 , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))## upward quark line
qout   = diagram.line(outX,vx , color='black', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))#,arrow=True)
p2     = diagram.line(v1, out2, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
gamma  = diagram.line(vqed, vx, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)
gamma2 = diagram.line(v1, v4, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)

###################################################################################
e1.text(r"$e$" ,fontsize=40, color='k')
e2.text(r"$e$" ,fontsize=40, color='k')
p1.text(r"$p$" ,fontsize=40)
p2.text(r"$p^{(*)}$" ,fontsize=40)
###################################################################################
diagram.text(0.85, 0.6,r"$\mu$",fontsize=40,color='k')
diagram.text(0.85, 0.4,r"$\mu$",fontsize=40,color='k')
gamma.text(r"$\gamma$",fontsize=40,color='g')
diagram.text(0.32, 0.375,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_mumubar1.jpg')
matplotlib.pyplot.savefig('plot_mumubar1.pdf')
matplotlib.pyplot.show()

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.3,.3), marker='')
vqed = diagram.vertex(xy=(.3,.7), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.8,.65), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.8,.6), marker='') ###
outqb   = diagram.vertex(xy=(.8,.4), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
e2     = diagram.line(vqed, out1, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qb     = diagram.line(v4, outqb , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qloop  = diagram.line(vx,v4 , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))## upward quark line
qout   = diagram.line(outX,vx , color='black', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))#,arrow=True)
p2     = diagram.line(v1, out2, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
gamma  = diagram.line(vqed, v4, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)
gamma2 = diagram.line(v1, vx, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)

###################################################################################
e1.text(r"$e$" ,fontsize=40, color='k')
e2.text(r"$e$" ,fontsize=40, color='k')
p1.text(r"$p$" ,fontsize=40)
p2.text(r"$p^{(*)}$" ,fontsize=40)
###################################################################################
diagram.text(0.85, 0.6,r"$\mu$",fontsize=40,color='k')
diagram.text(0.85, 0.4,r"$\mu$",fontsize=40,color='k')
gamma.text(r"$\gamma$",fontsize=40,color='g')
diagram.text(0.3, 0.4,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_mumubar2.jpg')
matplotlib.pyplot.savefig('plot_mumubar2.pdf')
matplotlib.pyplot.show()

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.4,.2), marker='')
vqed = diagram.vertex(xy=(.4,.8), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.7,.5), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.95,.5), marker='') ###
outqb   = diagram.vertex(xy=(.8,.4), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, style='wiggly', color='g', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, style='wiggly', color='g', lw=lw, arrow_param=dict(color='g', length=0.08, width=0.02))
e2     = diagram.line(outx1, vqed, style='dashed', color='green', lw=lw, arrow_param=dict(color='g', length=0.08, width=0.02))
# qb     = diagram.line(v4, outqb , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
# qloop  = diagram.line(vx,v4 , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))## upward quark line
# qout   = diagram.line(outX,vx , color='black', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))#,arrow=True)
p2     = diagram.line(v1, outx1, color='g',style='dashed', lw=lw, arrow_param=dict(color='g', length=0.08, width=0.02))
gamma  = diagram.line(vqed, v1, style='dashed', color='green', lw=lw, nwiggles=7, amplitude=0.013,arrow_param=dict(color='g', length=0.08, width=0.02))
gamma2 = diagram.line(outx1, outX, style='dotted', color='k', lw=lw, nwiggles=7, amplitude=0.013)

###################################################################################
e1.text(r"$\gamma$" ,fontsize=40, color='g')
e2.text(r"$W$" ,fontsize=40, color='g')
p1.text(r"$\gamma$" ,fontsize=40, color='g')
p2.text(r"$W$" ,fontsize=40, color='g')
###################################################################################
# diagram.text(0.85, 0.6,r"$\mu$",fontsize=40,color='k')
# diagram.text(0.85, 0.4,r"$\mu$",fontsize=40,color='k')
gamma.text(r"$W$",fontsize=40,color='g')
gamma2.text(r"$H$",fontsize=40,color='k')
# diagram.text(0.3, 0.4,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_higgs.jpg')
matplotlib.pyplot.savefig('plot_higgs.pdf')
matplotlib.pyplot.show()

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.4,.2), marker='')
vqed = diagram.vertex(xy=(.4,.8), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.7,.5), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.95,.5), marker='') ###
outqb   = diagram.vertex(xy=(.8,.4), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, style='wiggly', color='g', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, style='wiggly', color='g', lw=lw, arrow_param=dict(color='g', length=0.08, width=0.02))
e2     = diagram.line(outx1, vqed, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
# qb     = diagram.line(v4, outqb , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
# qloop  = diagram.line(vx,v4 , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))## upward quark line
# qout   = diagram.line(outX,vx , color='black', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))#,arrow=True)
p2     = diagram.line(v1, outx1, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
gamma  = diagram.line(vqed, v1,  color='k', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))
gamma2 = diagram.line(outx1, outX, style='dotted', color='k', lw=lw, nwiggles=7, amplitude=0.013)

###################################################################################
e1.text(r"$\gamma$" ,fontsize=40, color='g')
e2.text(r"$q$" ,fontsize=40, color='k')
p1.text(r"$\gamma$" ,fontsize=40, color='g')
p2.text(r"$q$" ,fontsize=40, color='k')
###################################################################################
# diagram.text(0.85, 0.6,r"$\mu$",fontsize=40,color='k')
# diagram.text(0.85, 0.4,r"$\mu$",fontsize=40,color='k')
gamma.text(r"$q$",fontsize=40,color='k')
gamma2.text(r"$H$",fontsize=40,color='k')
# diagram.text(0.3, 0.4,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_higgs2.jpg')
matplotlib.pyplot.savefig('plot_higgs2.pdf')
matplotlib.pyplot.show()

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.3,.3), marker='')
vqed = diagram.vertex(xy=(.3,.7), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.8,.65), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.8,.6), marker='') ###
outqb   = diagram.vertex(xy=(.8,.4), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
e2     = diagram.line(vqed, out1, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qb     = diagram.line(v4, outqb , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qloop  = diagram.line(vx,v4 , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))## upward quark line
qout   = diagram.line(outX,vx , color='black', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))#,arrow=True)
p2     = diagram.line(v1, out2, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
gamma  = diagram.line(vqed, vx, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)
gamma2 = diagram.line(v1, v4, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)

###################################################################################
e1.text(r"$e$" ,fontsize=40, color='k')
e2.text(r"$e$" ,fontsize=40, color='k')
p1.text(r"$p$" ,fontsize=40)
p2.text(r"$p^{(*)}$" ,fontsize=40)
###################################################################################
diagram.text(0.85, 0.6,r"$\tau^+$",fontsize=40,color='k')
diagram.text(0.85, 0.4,r"$\tau^-$",fontsize=40,color='k')
gamma.text(r"$\gamma$",fontsize=40,color='g')
diagram.text(0.32, 0.375,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_tautaubar1.jpg')
matplotlib.pyplot.savefig('plot_tautaubar1.pdf')
matplotlib.pyplot.show()

# %%
import matplotlib
# matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

pom_style = dict(arrow=False, style = 'double',linewidth=7)
t_style = dict(style='elliptic dashed',
               ellipse_excentricity=-1.2, ellipse_spread=.3,
               arrow=True,ellipse_position='down',lw=2)

diagram = Diagram(ax)
#diagram.text(.4,0.9,"Diffractive Deep Inelastic Scattering", fontsize=40)
in1  = diagram.vertex(xy=(.1,.8), marker='')
in2  = diagram.vertex(xy=(.1,.2), marker='')
out1 = diagram.vertex(xy=(.9,.8), marker='')
out2 = diagram.vertex(xy=(.9,.2), marker='')
v1   = diagram.vertex(xy=(.3,.3), marker='')
vqed = diagram.vertex(xy=(.3,.7), marker='')
v3   = diagram.vertex(xy=(.4,.45), marker='')## upper side of pomeron blob
v4   = diagram.vertex(xy=(.4,0.4), marker='')## lower side of pomeron blob
v5   = diagram.vertex(xy=(.425,0.425), marker='') ## front of pomeron blob
vx   = diagram.vertex(xy=(.4,.6), marker='')  ## lower qed vertex
v1p  = diagram.vertex(xy=(.425,.35),marker='')
v1pp = diagram.vertex(xy=(.375,.35),marker='')
v1t  = diagram.vertex(xy=(.3,.3),marker='')
v2t  = diagram.vertex(xy=(.52,.27),marker='')
vqqg = diagram.vertex(xy=(.52,.65),marker='')

l1plus  = diagram.vertex(xy=(.95,.8), marker='')
l2plus  = diagram.vertex(xy=(.95,.6), marker='')
l1minus = diagram.vertex(xy=(.95,.4), marker='')
l2minus = diagram.vertex(xy=(.95,.2), marker='')
outx1   = diagram.vertex(xy=(.8,.65), marker='')###
outx2   = diagram.vertex(xy=(.8,.55), marker='')###
outX    = diagram.vertex(xy=(.8,.6), marker='') ###
outqb   = diagram.vertex(xy=(.8,.4), marker='') ###
vtautop = diagram.vertex(xy=(.55,.6), marker='') ###
vtaubot = diagram.vertex(xy=(.55,.425), marker='') ###
outx3   = diagram.vertex(xy=(.8,.475), marker='')###
outx4   = diagram.vertex(xy=(.8,.375), marker='')###


lw = 5
e1     = diagram.line(in1, vqed, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
p1     = diagram.line(in2, v1, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
e2     = diagram.line(vqed, out1, color='k', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qb     = diagram.line(v4, outqb , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))
qloop  = diagram.line(vx,v4 , color='black', lw=lw, arrow_param=dict(color='k', length=0.08, width=0.02))## upward quark line
qout   = diagram.line(outX,vx , color='black', lw=lw,arrow_param=dict(color='k', length=0.08, width=0.02))#,arrow=True)
p2     = diagram.line(v1, out2, color='blue', lw=lw, arrow_param=dict(color='blue', length=0.08, width=0.02))
gamma  = diagram.line(vqed, v4, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)
gamma2 = diagram.line(v1, vx, style='wiggly', color='green', lw=lw, nwiggles=7, amplitude=0.013)

###################################################################################
e1.text(r"$e$" ,fontsize=40, color='k')
e2.text(r"$e$" ,fontsize=40, color='k')
p1.text(r"$p$" ,fontsize=40)
p2.text(r"$p^{(*)}$" ,fontsize=40)
###################################################################################
diagram.text(0.85, 0.6,r"$\tau^+$",fontsize=40,color='k')
diagram.text(0.85, 0.4,r"$\tau^-$",fontsize=40,color='k')
gamma.text(r"$\gamma$",fontsize=40,color='g')
diagram.text(0.3, 0.4,r"$\gamma$",fontsize=40,color='g')
######################################################################
diagram.plot()
matplotlib.pyplot.savefig('plot_tautaubar2.jpg')
matplotlib.pyplot.savefig('plot_tautaubar2.pdf')
matplotlib.pyplot.show()
